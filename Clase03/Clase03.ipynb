# %% [markdown]
# # Ejercicios de programación
# ## Tipos de datos

# %%
nombre = "Haydé tiene 25 años" # Esta es una variable de text "str"
print(nombre)
# Out:
# Haydé tiene 25 años

# %%
edad = 35 # Esta es una variable de numero "int"
print(edad)
# Out:
# 35

# %%
estatura = 1.76 # Esta es una variable de numero "float"
print(estatura)
# Out:
# 1.76

# %%
felicidad = True # Esta es una variable booleana "bool"
print(felicidad)
# Out:
# True

# %%
type(nombre)
# Out:
# str

# %%
type(edad)
# Out:
# int

# %%
type(estatura)
# Out:
# float

# %%
type(felicidad)
# Out:
# bool

# %%
comida_favorita = "pozole"

# %%
print(comida_favorita)
# Out:
# pozole

# %%
comida_favorita = "aguachile"

# %%
print(comida_favorita)
# Out:
# aguachile

# %%
# Operaciones con diferentes tipos de datos
5 + 5
# Out:
# 10

# %%
"a" + "b"
# Out:
# 'ab'

# %%
suma = 5 + 5 #suma de enteros
print (suma)
# Out:
# 10

# %%
concat = "a" + "b" #concatenación de cadenas de text
print(concat)
# Out:
# ab

# %%
prueba = comida_favorita + " " + str(estatura)
print(prueba)
# Out:
# aguachile 1.76

# %%
type(estatura)
# Out:
# float

# %%
telefono = "3319753470"

# %%
telefono + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 telefono + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(telefono) + 1
# Out:
# 3319753471

# %%
# Estructuras de control 
# Condicionales       "==" igual, "!=" diferente, "<" menor que, ">" mayor que, <= "menor que o igual", >= "mayor que o igual"
felicidad = True

if felicidad != True:
    print("Toy bien felipe")
    resultado = 2+2
    if resultado > 3:
        print(resultado)
    else:
        print("No fue mayor que 3")
else:
    print("Toy bien sad")
# Out:
# Toy bien sad

# %%
# Bucles

prueba = 0
while prueba < 5:
    print("Voy en: " + str(prueba))
    prueba = prueba + 1
# Out:
# Voy en: 0
# Voy en: 1
# Voy en: 2
# Voy en: 3
# Voy en: 4

# %%
# Operaciones con cadenas de texto
version = 3.9
mensaje = "Estás usando python " + str(version)
print(mensaje)
# Out:
# Estás usando python 3.9

# %%
texto = "Hola mundo"

# %%
texto.upper()
# Out:
# 'HOLA MUNDO'

# %%
texto.replace("Hola","Adios")
# Out:
# 'Adios mundo'

# %%
# Listas

mi_lista = [1,2,3, "python", True]

# %%
mi_lista
# Out:
# [1, 2, 3, 'python', True]

# %%
mi_lista[0]
# Out:
# 1

# %%
len(mi_lista)
# Out:
# 5

# %%
# agregar valores 
mi_lista.append(4)
mi_lista
# Out:
# [1, 2, 3, 'python', True, 4]

# %%
mi_lista.insert(2,[99,15])
mi_lista
# Out:
# [1, 2, [99, 15], 3, 'python', True, 4]

# %%
mi_lista[2]
# Out:
# [99, 15]

# %%
mi_lista[2][0]
# Out:
# 99

# %%
mi_lista.remove(4)
mi_lista
# Out:
# [1, 2, [99, 15], 3, 'python', True]

# %%
mi_lista.pop()
mi_lista
# Out:
# [1, 2, [99, 15], 3, 'python']

# %%
mi_lista.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 mi_lista.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
lista2 = [3,5,1,7,9]
lista2.sort()
lista2
# Out:
# [1, 3, 5, 7, 9]

# %%
lista3 = ["b","a","c"]
lista3.sort()
lista3
# Out:
# ['a', 'b', 'c']

# %%
lista2.reverse()
lista2
# Out:
# [9, 7, 5, 3, 1]

# %%
lista2.append(9)
lista2
# Out:
# [9, 7, 5, 3, 1, 9]

# %%
lista2.count(9)
# Out:
# 2

# %%
lista2.pop(0)
lista2
# Out:
# [7, 5, 3, 1, 9]

# %%
lista2.pop(3)
lista2
# Out:
# [7, 5, 3, 9]

# %%
resultado = "Hola,mi,nombre,es,Hayde".split(",")

# %%
resultado
# Out:
# ['Hola', 'mi', 'nombre', 'es', 'Hayde']

# %%
# Tuplas
mi_tupla = (1,2,3,"Python")

# %%
mi_tupla
# Out:
# (1, 2, 3, 'Python')

# %%
mi_tupla.append(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 mi_tupla.append(1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
mi_tupla.count(2)
# Out:
# 1

# %%
mi_tupla.index("Python")
# Out:
# 3

# %%
lista2
# Out:
# [7, 5, 3, 9]

# %%
for i in lista2:
    print(i)
# Out:
# 7
# 5
# 3
# 9

# %%
for b in mi_tupla:
    print(b)
# Out:
# 1
# 2
# 3
# Python

# %%
list(mi_tupla)
# Out:
# [1, 2, 3, 'Python']

# %%
tuple(lista2)
# Out:
# (7, 5, 3, 9)

# %%
# Diccionarios

mi_dict = {"nombre":"Python","version":"3.9","activo":True, "valores":[1,2,3]}
mi_dict
# Out:
# {'nombre': 'Python', 'version': '3.9', 'activo': True, 'valores': [1, 2, 3]}

# %%
mi_dict["nombre"]
# Out:
# 'Python'

# %%
mi_dict["version"]
# Out:
# '3.9'

# %%
mi_dict["activo"]
# Out:
# True

# %%
mi_dict["valores"]
# Out:
# [1, 2, 3]

# %%
mi_dict["valores"][0]
# Out:
# 1

# %%
mi_dict["nombre"] = "Py"
mi_dict
# Out:
# {'nombre': 'Py',
#  'version': '3.9',
#  'activo': True,
#  'valores': [1, 2, 3],
#  'extra': 1234}

# %%
mi_dict.keys() #ver todas mis claves
# Out:
# dict_keys(['nombre', 'version', 'activo', 'valores', 'extra'])

# %%
mi_dict.values() #ver todos mis valores
# Out:
# dict_values(['Py', '3.9', True, [1, 2, 3], 1234])

# %%
for key in mi_dict.keys():
    print( key + ":" + str(mi_dict[key]))
# Out:
# nombre:Py
# version:3.9
# activo:True
# valores:[1, 2, 3]
# extra:1234

# %%
for values in mi_dict.values():
    print(str(values))
# Out:
# Py
# 3.9
# True
# [1, 2, 3]
# 1234

# %%
mi_dict.items()
# Out:
# dict_items([('nombre', 'Py'), ('version', '3.9'), ('activo', True), ('valores', [1, 2, 3]), ('extra', 1234)])

# %%
for key, value in mi_dict.items():
    print(key + ":" + str(value))
# Out:
# nombre:Py
# version:3.9
# activo:True
# valores:[1, 2, 3]
# extra:1234

# %%
mi_dict.pop("activo")
# Out:
# True

# %%
mi_dict
# Out:
# {'nombre': 'Py', 'version': '3.9', 'valores': [1, 2, 3], 'extra': 1234}

# %%
mi_dict.clear()

# %%
mi_dict
# Out:
# {}

# %%
mi_dict.get("version", "no existe")
# Out:
# 'no existe'

# %%
#Slicing
frase = "Hola como estas"
frase[0]
# Out:
# 'H'

# %%
frase[5]
# Out:
# 'c'

# %%
palabra = frase[0:4]
palabra
# Out:
# 'Hola'

# %%
frase[5:10] + frase[0:5] + frase[10:]
# Out:
# 'como Hola estas'

# %%
frase[10:]
# Out:
# 'estas'

# %%
frase[:5]
# Out:
# 'Hola '

# %%
# Funciones
def saludar():
    print("Hola")

# %%
saludar()
# Out:
# Hola

# %%
def saludar2(nombre):
    print("Hola " + nombre)

# %%
saludar2("Brenda")
# Out:
# Hola Brenda

# %%
saludar2("HErminio")
# Out:
# Hola HErminio

# %%
def sumar(a,b):
    return a + b

# %%
sumar(1,2)
# Out:
# 3

# %%
resultado = sumar(1,2)

# %%
resultado
# Out:
# 3

# %%
# 2. Escribir una función que reciba una tupla con n cantidad de nombres, y para cada nombre imprima 
# el mensaje Estimado,*inserte nombre aquí* vote por mí.

def voto(tupla):
    for elemento in tupla:
        print("Estimado "+str(elemento)+" vote por mi")

# %%
voto(mi_tupla)
# Out:
# Estimado 1 vote por mi
# Estimado 2 vote por mi
# Estimado 3 vote por mi
# Estimado Python vote por mi

# %%
tupli = (1,2)
tupli2 = (2,8)
tupli3 = (5,7)

# %%
if tupli[0] in tupli3 or tupli[1] in tupli3:
    print("si esta")
else:
    print("no esta")
# Out:
# no esta

# %%
if tupli[1] in tupli2 and tupli[1] > 3:
    print("Si cumple todas las condiciones")
else:
    print("No cumple todas las condiciones")
# Out:
# No cumple todas las condiciones
