# %%
print("Hello world")
# Out:
# Hello world

# %%
nombre = "Hayde Martijoisjisdjinez"

# %%
print(nombre)
# Out:
# Hayde Martijoisjisdjinez

# %%
numerofavorito = 8

# %%
print(numerofavorito)
# Out:
# 8

# %%
print(nombre)
# Out:
# Hayde
