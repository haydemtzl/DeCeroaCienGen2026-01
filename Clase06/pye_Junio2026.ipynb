# %%
# Import pandas
import pandas as pd
import numpy as np

# %%
# Cargar mis datos como dataframe 
data = pd.read_csv("notes.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Visualizar los primeros 5 renglones de mi dataset
data.head()
# Out:
#     Nombre  nota
# 0  Araceli     9
# 1   Manuel     5
# 2    Pablo     7
# 3    Iñigo     4
# 4    Mario     3

# %%
# Visualizar head con más renglones
data.head(2)
# Out:
#     Nombre  nota
# 0  Araceli     9
# 1   Manuel     5

# %%
# Función que me permite ver la estadistica descriptiva de las columnas númericas de mi dataset
data.describe()
# Out:
#             nota
# count  13.000000
# mean    5.615385
# std     2.364264
# min     2.000000
# 25%     4.000000
# 50%     5.000000
# 75%     7.000000
# max    10.000000

# %%
# Yo puedo accesar a cada columna de un dataframe como si fuera un diccionario, 
# en donde el header es la clave y el valor va a ser una lista con todos los datos
# de los renglones de esa respectiva columna

#Accesando a la columna nombre
data["Nombre"]
# Out:
# 0      Araceli
# 1       Manuel
# 2        Pablo
# 3        Iñigo
# 4        Mario
# 5         Raul
# 6     Verónica
# 7        Dario
# 8        Laura
# 9       Silvia
# 10     Eduardo
# 11      Susana
# 12       María
# Name: Nombre, dtype: object

# %%
#Accesando a la columna nota
data["nota"]
# Out:
# 0      9
# 1      5
# 2      7
# 3      4
# 4      3
# 5      4
# 6      6
# 7     10
# 8      4
# 9      6
# 10     2
# 11     8
# 12     5
# Name: nota, dtype: int64

# %%
# USANDO PANDAS
# Calculo de la media
media = data["nota"].mean()
media
# Out:
# 5.615384615384615

# %%
# Calculo de la mediana
mediana = data["nota"].median()
mediana
# Out:
# 5.0

# %%
# Calculo de la moda
moda = data["nota"].mode()
print("la moda " + str(moda))
# Out:
# la moda 0    4
# Name: nota, dtype: int64

# %%
# Calculo del rango 
rango = data["nota"].max() - data["nota"].min()
print(rango)
# Out:
# 8

# %%
# Calculando la media con numpy
np.mean(data["nota"])
# Out:
# 5.615384615384615

# %%
np.median(data["nota"])
# Out:
# 5.0

# %%
# Varianza y desviación estandar de los perritos
peyitos = [600,470,170,430,300]
np.mean(peyitos)
# Out:
# 394.0

# %%
np.median(peyitos)
# Out:
# 430.0

# %%
np.var(peyitos)
# Out:
# 21704.0

# %%
np.std(peyitos)
# Out:
# 147.32277488562318
